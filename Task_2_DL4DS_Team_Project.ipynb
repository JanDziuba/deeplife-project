# %% [markdown]
# # Deep Learning for Life Sciences - Team Assignment
#
# Recent progress in spatial tissue imaging has resulted in the emergence of many new technologies that enable measurements of multiple biological markers at the subcellular level. One such technology is IMC (Imaging Mass Cytometry), developed at [BodemillerLab](https://www.bodenmillerlab.com/#/) in Zurich. [Here](https://www.nature.com/articles/s41586-019-1876-x), you can read how this technology has enabled massive progress in understanding the mechanisms behind breast cancer.
#
# One application of this technology is analyzing the data from the [Immucan](https://immucan.eu/) consortium, where data from patients with different cancer types is analyzed using various techniques, including IMC.
#
# # Task
# [Cell typing](https://en.wikipedia.org/wiki/Cell_type), a fundamental step in cellular data analysis, involves assigning each cell to a specific type. In this assignment, you will perform cell typing based on the manually expert-annotated data. At the high level, your task will be to:
#
# 1. **Perform EDA (exploratory data analysis) (3pts)** - in the form of an approx. 5-minute presentation - you will present your insight about the data you were provided with.
# 2. **Apply a baseline technique for the classification (3pts).** Each team should try at least three popular techniques on the provided data. Among these three popular techniques, there should be:
#     - one linear baseline (e.g., multiclass logistic regression, SVM, etc.),
#     - one gradient boosting technique (e.g., XGBoost, CatBoost, etc.),
#     - one additional technique of your choice.
# 3. **Apply one of the state-of-the-art methods pre-selected by Immucan researchers (5pts)** (see description below).
#
# ## State-of-the-art methods
# We will assign each team with one of the pre-selected state-of-the-art methods:
# - [cellSighter](https://www.nature.com/articles/s41467-023-40066-7),
# - [Stellar](https://www.nature.com/articles/s41592-022-01651-8), (additional [biorxiv](https://www.biorxiv.org/content/10.1101/2021.11.24.469947v3) URL),
# - [Pixie](https://www.nature.com/articles/s41467-023-40068-5),
# - [Astir](https://astir.readthedocs.io/en/latest/index.html),
# - [Celesta](https://www.nature.com/articles/s41592-022-01498-z) (additional [biorxiv](https://www.biorxiv.org/content/10.1101/2022.02.02.478888v1) URL),
# - [CSPOT](https://www.biorxiv.org/content/10.1101/2023.11.15.567196v1),
# - [STARLING](https://www.biorxiv.org/content/10.1101/2024.02.29.582827v2).
#
# We will assign a method to a team based on the random choice driven by your preferences. The voting procedure will be as follows: each team must set their preferences in this [sheet](https://docs.google.com/spreadsheets/d/1wtdwD7O49GHmPmPPFYF9WcjlDG0VRwf6MOWh3aV0iaw/edit?usp=sharing) (where you should also write your team name and members). To each method, your team can assign from 0 to 5 points (the more points, the higher the chance of getting a method). Each team has 10 points in total. In case when there are more teams than selected methods, the most popular method will be assigned to more than one team. Please e-mail marcin.mozejko@student.uw.edu.pl once you filled the spreadsheet for your team.
#
# # Data
# We will provide you with [training data](https://drive.google.com/file/d/1-0YOHE1VoTRWqfBJLHQorGcHmkhCYvqW/view?usp=sharing) and a hold-out test set. The training data will be provided from the start of the assignment, and the test data will be provided on May 9th during the grading of your task. Both datasets are in the same format. In the code below the task description you will be provided with a brief data overview.
#
# # Grading
# 1. **EDA** - A maximal number of points (3) will be assigned when a team will present:
#     - A general data overview,
#     - Correlation patterns between markers and cell types (at least 3) - with a biological explanation,
#     - Three biologically driven patterns of intertype marker differentiation (e.g., Tumor PDL1+ vs Tumor PDL1-, Mac CD206+ vs Mac CD206-, etc.),
# 2. **Baseline techniques**: For proper implementation of each of the three methods, we will award 1 point,
# If possible, a method should enable random seed/state-based reproducibility,
# 3. **State-of-the-art methods**: A proper application of the existing method will be awarded with 5 pts.
#
# ## Metrics
#
# Please report:
# - overall Accuracy, and `macro-f1`,
# - per cell type `average_precision` and `AUC`.
#
# ## Additional Compute
#
# In case you need an additional compute - please contant the author of the task: marcin.mozejko@student.uw.edu.pl
#
# ## Deliverables
# Each team should provide a git repository with a code and analysis. In each of the repositories, there should be:
# 1. Instructions on how to set up the environment (e.g., virtual env, docker, etc.) to run your method (1pt),
# 2. Instructions on how to pre-train baselines and state-of-the-art methods on new data (in the same format as the one provided with the task). For each method, the output should be a table where each cell will be assigned cell-type probabilities (if available) and a final cell-type prediction (2 pts).
# 3. Instructions on how to apply your pre-trained baseline methods and assigned state-of-the-art methods to new data (in the same format as the one provided with the task). For each method, the output should be a table where each cell will be assigned cell-type probabilities (if available) and a final cell-type prediction (1pts).
#
# ## Additional points:
# - A team with the highest scoring baseline method on the test data will be awarded three activity points,
# - Any creative modification of the state-of-the-art method will be awarded with up to 3 activity points,
# - Any interesting biological insight gained from EDA or baseline/method training will be awarded with up to 3 activity points,
# - Any uncertainty-based analysis of any model result will be awarded with one activity point.
#
# ## Project Timeline
# - **April 11th** - release of the task, and the state-of-the-art method voting spreadsheet,
# - **April 15th, 23:59** - end of the state-of-the-art method voting,
# - **April 18th** - assignment of the state-of-the-art methods to the teams,
# - **May 9th** - final presentation, release of the test data.
#
# # Contact
#
# In case of any questions - contact **Marcin Możejko** (marcin.mozejko@student.uw.edu.pl) - the author of the task.
#
# # Data Overview
#
# Let us start with appropriate imports:

# %%
# !pip install anndata
# !pip install delayedarray
# !pip install pyometiff
# Out:
# Collecting anndata
#   Downloading anndata-0.10.7-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 kB 1.2 MB/s eta 0:00:00
# Collecting array-api-compat!=1.5,>1.4 (from anndata)
#   Downloading array_api_compat-1.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata) (1.2.1)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.10/dist-packages (from anndata) (3.9.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata) (8.4.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from anndata) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from anndata) (24.0)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from anndata) (2.0.3)
# Requirement already satisfied: scipy>1.8 in /usr/local/lib/python3.10/dist-packages (from anndata) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (1.16.0)
# Installing collected packages: array-api-compat, anndata
# Successfully installed anndata-0.10.7 array-api-compat-1.6
# Collecting delayedarray
#   Downloading DelayedArray-0.5.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 604.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from delayedarray) (1.25.2)
# Collecting biocutils (from delayedarray)
#   Downloading biocutils-0.1.5-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: biocutils, delayedarray
# Successfully installed biocutils-0.1.5 delayedarray-0.5.0
# Collecting pyometiff
#   Downloading pyometiff-1.0.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pyometiff) (4.9.4)
# Requirement already satisfied: tifffile>2020.10.1 in /usr/local/lib/python3.10/dist-packages (from pyometiff) (2024.4.24)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyometiff) (1.25.2)
# Collecting imagecodecs (from pyometiff)
#   Downloading imagecodecs-2024.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 29.4 MB/s eta 0:00:00
# Installing collected packages: imagecodecs, pyometiff
# Successfully installed imagecodecs-2024.1.1 pyometiff-1.0.0

# %% [markdown]
# Now - download the training data from [here](https://drive.google.com/file/d/1-0YOHE1VoTRWqfBJLHQorGcHmkhCYvqW/view?usp=sharing).
#
# Unzip the archive and set `PATH_TO_FOLDER` to a path where you unzipped the data:

# %%
import os
import zipfile
from google.colab import drive

import anndata


drive.mount('/content/drive/') # use if you plan to use colab.


PATH_TO_FOLDER = '/content/drive/MyDrive/train/train'
TRAIN_DATA_PATH = '/content/drive/MyDrive/train/train'
ORIGINAL_IMAGE_DATA_SUBDIR = 'images_masks'
ORIGINAL_MASKS_SUBDIR = 'masks'
ORIGINAL_IMAGES_SUBDIR = 'img'

if PATH_TO_FOLDER is None:
    raise ValueError('Please set PATH_TO_FOLDER to a path with unzipped training data.')

ANNDATA_PATH = 'cell_data.h5ad'
TRAIN_ANNDATA_PATH = os.path.join(TRAIN_DATA_PATH, ANNDATA_PATH)
TRAIN_IMAGE_DATA_DIR = os.path.join(TRAIN_DATA_PATH, ORIGINAL_IMAGE_DATA_SUBDIR)
TRAIN_IMAGE_DATA_IMAGES = os.path.join(TRAIN_IMAGE_DATA_DIR, ORIGINAL_IMAGES_SUBDIR)
TRAIN_IMAGE_DATA_MASKS = os.path.join(TRAIN_IMAGE_DATA_DIR, ORIGINAL_MASKS_SUBDIR)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Data overview
#
# A provided training data consist of two entities:
# - a tabular data (stored in a `cell_data.h5ad` file),
# - image data - stored in `images_masks` directory.
#
# Let us start with having a look at the tabular data:

# %%
train_anndata = anndata.read_h5ad(TRAIN_ANNDATA_PATH)
train_anndata.obs.head()
# Out:
#                                                                                                 image  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
#
#                                                                                             sample_id  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01...
#
#                                                     ObjectNumber       Pos_X  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           1.0  300.846154
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           3.0   26.982143
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           5.0  309.083333
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           7.0  431.916667
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           8.0  116.931034
#
#                                                        Pos_Y  area  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  0.692308  13.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  0.928571  56.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  0.750000  12.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  0.750000  12.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  1.206897  29.0
#
#                                                     major_axis_length  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           6.094800
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...          21.520654
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           5.294329
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           5.294329
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           9.216670
#
#                                                     minor_axis_length  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           2.780135
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           3.368407
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           2.862220
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           2.862220
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...           4.112503
#
#                                                     eccentricity  width_px  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...      0.889904     600.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...      0.987675     600.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...      0.841267     600.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...      0.841267     600.0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...      0.894932     600.0
#
#                                                     ...  flag_tumor  PD1_pos  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  ...           0        0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  ...           0        0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  ...           0        0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  ...           0        0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  ...           0        0
#
#                                                    Ki67_pos cleavedPARP_pos  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0               0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0               0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0               0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0               0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0               0
#
#                                                    GrzB_pos  tumor_patches  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0              1
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0              0
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0              1
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0              1
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...        0              1
#
#                                                    distToCells CD20_patches  \
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...    8.773580
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...   72.247393
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...   16.982199
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...   -8.314676
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  -15.358007
#
#                                                             Batch cell_labels
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  Batch20191023    MacCD163
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  Batch20191023       Mural
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  Batch20191023          DC
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  Batch20191023       Tumor
# IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-...  Batch20191023       Tumor
#
# [5 rows x 39 columns]

# %% [markdown]
# Train `anndata` `obs` dataframe stores the information about cells. Each row in this table represent an information about a single cell. It has the following columns that are interesting for your analysis:
# - `image` - name of the image file from which a cell was obtained,
# - `sample_id` - name of the patient sample from which a given image was obtained,
# - `ObjectNumber` - a cell number within a given image (note that it starts from 1),
# - `Pos_X`, `Pos_Y` - a spatial position of the cell one the image,
# - `area`, `major_axis_length`, `minor_axis_length`, `eccentricity`, `width_px`, `height_px` - shape-derived features of a cell,
# - `Batch` - a batch in which a sample was used,
# - `cell_labels` - your target cell type annotations. **THIS IS WHAT YOUR MODELS AIM TO PREDICT!**

# %% [markdown]
# `train_anndata.var` stores the information about the marker names. Please use the `marker` column in your analysis:

# %%
train_anndata.var.head()
# Out:
#   channel  use_channel     marker
# 0     Y89            1        MPO
# 1   In113            0  HistoneH3
# 2   In115            1        SMA
# 3   Pr141            1       CD16
# 4   Nd142            1       CD38

# %% [markdown]
# `train_anndata.layers['exprs']` with shape `(train_anndata.obs.shape[0], train_anndata.var.shape[0])` stores the matrix with marker expressions for each cell:

# %%
train_anndata.layers['exprs']
# Out:
# array([[0.        , 1.81998789, 0.50264976, ..., 0.42427316, 4.76113044,
#         5.30135121],
#        [0.13592021, 2.39308671, 1.1369607 , ..., 0.1186204 , 5.02924127,
#         5.53076447],
#        [0.16590455, 2.24491655, 1.39633367, ..., 0.01514088, 4.41838981,
#         4.81592274],
#        ...,
#        [0.11088375, 3.52028872, 0.31083376, ..., 0.10251545, 4.30306951,
#         4.82609754],
#        [0.15094134, 4.2149584 , 2.65164581, ..., 0.08397474, 4.8224562 ,
#         5.36166154],
#        [0.49059059, 5.8223478 , 1.61541043, ..., 0.22942113, 4.44821169,
#         5.01081325]])

# %% [markdown]
# # Image Data
#
# We will now show you how to connect information from the tabular data with the image information. Let us have a look at the third cell in the table:

# %%
train_anndata.obs.iloc[213120]
# Out:
# image                   IMMUcan_Batch20220309_S-220114-00032_006.tiff
# sample_id                    IMMUcan_Batch20220309_S-220114-00032_006
# ObjectNumber                                                   2111.0
# Pos_X                                                      129.157895
# Pos_Y                                                      405.921053
# area                                                             38.0
# major_axis_length                                            7.557543
# minor_axis_length                                            6.558698
# eccentricity                                                 0.496853
# width_px                                                        600.0
# height_px                                                       600.0
# acquisition_id                                                    6.0
# SlideId                                                S-220114-00032
# Study                                                    190370_SPECT
# Box.Description                                      Slide_IMC-TIS-01
# Position                                                            2
# SampleId                                 10089567-SPECT-VAR-TIS-01-PB
# Indication                                                      BREAS
# BatchId                                                 Batch20220309
# SubBatchId                                           Batch20220309_04
# ROI                                                                 2
# ROIonSlide                                                          6
# includeImage                                                        1
# flag_no_cells                                                       0
# flag_no_ROI                                                         0
# flag_total_area                                                     0
# flag_percent_covered                                                0
# small_cell                                                          0
# celltypes                                                         pDC
# flag_tumor                                                          0
# PD1_pos                                                             0
# Ki67_pos                                                            0
# cleavedPARP_pos                                                     0
# GrzB_pos                                                            0
# tumor_patches                                                       1
# distToCells                                                 14.684064
# CD20_patches
# Batch                                                   Batch20220309
# cell_labels                                                       pDC
# Name: IMMUcan_Batch20220309_S-220114-00032_006.tiff_2111, dtype: object

# %% [markdown]
# We can see that the image name assigned to this cell is `IMMUcan_batch20191023_10032145-THOR-VAR-TIS-01-IMC-01_002.tiff`. Additionally - please note that the `ObjectNumber` is equal to 5. Now there are two type of image data:
#
# - marker data (stored in `images_masks/img` subdir),
# - mask data (stored in `images_masks/masks` subdir).
#
# Let us have a look at the image and mask from which a given cell was taken:

# %%
import pyometiff
import matplotlib.pyplot as plt


image_name = train_anndata.obs.iloc[236790]['image']
image_path = os.path.join(TRAIN_IMAGE_DATA_IMAGES, image_name)
mask_path = os.path.join(TRAIN_IMAGE_DATA_MASKS, image_name)

# %%
image_reader = pyometiff.OMETIFFReader(fpath=image_path)
mask_reader = pyometiff.OMETIFFReader(fpath=mask_path)


image_array, _, _ = image_reader.read()
mask_array, _, _ = mask_reader.read()

print(image_array.shape, mask_array.shape, train_anndata.shape)
# Out:
# WARNING:root:File /content/drive/MyDrive/train/train/images_masks/img/IMMUcan_Batch20220908_S-220729-00002_002.tiff has no OME-XML tags!
# WARNING:root:File /content/drive/MyDrive/train/train/images_masks/masks/IMMUcan_Batch20220908_S-220729-00002_002.tiff has no OME-XML tags!
# (40, 600, 600) (600, 600) (236791, 40)

# %% [markdown]
# In `mask_array` each pixel stores the information about which `ObjectNumber` cell a particular pixel belongs to:

# %%
plt.imshow(mask_array)

# %% [markdown]
# So the third cell in the table is located for pixel where `mask_array == 5` (because 5 is an `ObjectId` for this particular cell).
#
# `image_array` stores information about the marker expression. The channels are in the same ordering as in `train_anndata.var`. Now - let us have a look at the `SMA` expression for our image:

# %%
plt.imshow(image_array[2])

# %% [markdown]
# Seems bleaky? Let's have a look at the `SMA` marker distribution on this image:

# %%
plt.hist(image_array[2].flatten(), density=True)
# Out:
# (array([5.90694444e-02, 1.34671409e-03, 3.72798103e-04, 1.08739837e-04,
#         4.43766938e-05, 1.94783198e-05, 7.45257453e-06, 4.57317073e-06,
#         1.18563686e-06, 8.46883469e-07]),
#  array([  0. ,  16.4,  32.8,  49.2,  65.6,  82. ,  98.4, 114.8, 131.2,
#         147.6, 164. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Well, we can see that it is heavy-tailed. A standard way of dealing with this problem is to apply an `arcsinh(x/5.)` transform:

# %%
import numpy
plt.hist(numpy.arcsinh(image_array[2].flatten() / 5.0), density=True)
# Out:
# (array([1.85806939e+00, 1.94865008e-01, 1.62358736e-01, 6.55370526e-02,
#         5.19064611e-02, 3.25593867e-02, 1.60539553e-02, 6.44017233e-03,
#         1.98516652e-03, 3.91721822e-04]),
#  array([0.        , 0.4183808 , 0.8367616 , 1.2551424 , 1.6735232 ,
#         2.091904  , 2.51028479, 2.92866559, 3.34704639, 3.76542719,
#         4.18380799]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Well - much better. And this is how it looks on the image:

# %%
plt.imshow(numpy.arcsinh(image_array[2] / 5.))

# %% [markdown]
# **NOTE:** Please use an `arcsinh(x / 5.)` transform on your data.
#
# For more on the `imc` data preprocessing - look [here](https://bodenmillergroup.github.io/ImcSegmentationPipeline/prepro.html#conversion-from-ometiff-to-multi-channel-tiffs).

# %% [markdown]
# # Imports

# %%
import numpy as np
import anndata
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Data preparation

# %%
# Load tabular data
train_anndata = anndata.read_h5ad(TRAIN_ANNDATA_PATH)

# Apply arcsinh transform to marker expression data
exprs_data = train_anndata.layers['exprs']
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(exprs_data[:20000], train_anndata.obs['cell_labels'][:20000], test_size=0.2, random_state=42)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# 236791

# %% [markdown]
# # Function to evaluate model

# %%
def evaluateMethod(model):
  model.fit(X_train_scaled, y_train)

  y_pred = model.predict(X_test_scaled)

  overall_accuracy = accuracy_score(y_test, y_pred)
  macro_f1 = f1_score(y_test, y_pred, average='macro')

  print("Overall Accuracy:", overall_accuracy)
  print("Macro-F1:", macro_f1)

  class_labels = np.unique(y_test)
  class_label_to_index = {class_label: i for i, class_label in enumerate(class_labels)}

  for class_label in class_labels:
      class_index = class_label_to_index[class_label]
      y_pred_proba_pos_class = model.predict_proba(X_test_scaled)[:, class_index]

      y_test_binary = (y_test == class_label).astype(int)

      fpr, tpr, thresholds = roc_curve(y_test_binary, y_pred_proba_pos_class)

      auc_score = auc(fpr, tpr)
      print(f"AUC for class {class_label}: {auc_score}")

  print(classification_report(y_test, y_pred))

# %% [markdown]
# # Multiclass Logistic Regression

# %%
logistic_model = LogisticRegression(verbose=2, solver='lbfgs', multi_class='auto', max_iter=1000)
evaluateMethod(logistic_model)
# Out:
# Overall Accuracy: 0.942
# Macro-F1: 0.8905427652539039
# AUC for class B: 0.9986555116740741
# AUC for class BnT: 0.9994380831831324
# AUC for class CD4: 0.9978728483477823
# AUC for class CD8: 0.99860645066652
# AUC for class DC: 0.9963273068118319
# AUC for class HLADR: 0.9906154239019408
# AUC for class MacCD163: 0.9943136185400087
# AUC for class Mural: 0.9993385982749697
# AUC for class NK: 0.9942656440398537
# AUC for class Neutrophil: 0.9998568209265554
# AUC for class Treg: 0.9998089597860349
# AUC for class Tumor: 0.9954263547268926
# AUC for class pDC: 0.9997988068370686
# AUC for class plasma: 0.9982750016941948
#               precision    recall  f1-score   support
#
#            B       0.97      0.93      0.95       161
#          BnT       0.95      0.95      0.95       133
#          CD4       0.90      0.92      0.91       210
#          CD8       0.95      0.95      0.95       343
#           DC       0.87      0.82      0.84       174
#        HLADR       0.80      0.61      0.69        84
#     MacCD163       0.80      0.83      0.81       183
#        Mural       0.96      0.96      0.96       426
#           NK       0.67      0.71      0.69        14
#   Neutrophil       1.00      0.94      0.97        82
#         Treg       1.00      0.93      0.96        29
#        Tumor       0.96      0.98      0.97      2062
#          pDC       0.92      0.93      0.92        58
#       plasma       0.88      0.88      0.88        41
#
#     accuracy                           0.94      4000
#    macro avg       0.90      0.88      0.89      4000
# weighted avg       0.94      0.94      0.94      4000

# %% [markdown]
# # Gradient Boosting Cliassifier

# %%
gbc_model = GradientBoostingClassifier(n_estimators=30, max_features='sqrt', verbose=1)
evaluateMethod(gbc_model)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3708           29.14s
#          2           1.1836           27.63s
#          3           1.0360           24.06s
#          4           0.9409           21.84s
#          5           0.8552           20.29s
#          6           0.7846           18.99s
#          7           0.7071           18.29s
#          8           0.6470           18.02s
#          9           0.6018           17.52s
#         10           0.5598           16.99s
#         20           0.3073            7.73s
#         30           0.1969            0.00s
# Overall Accuracy: 0.9345
# Macro-F1: 0.848115055689239
# AUC for class B: 0.9963693961451529
# AUC for class BnT: 0.9900974313207378
# AUC for class CD4: 0.9974016836285966
# AUC for class CD8: 0.9960138749042333
# AUC for class DC: 0.9970047647373386
# AUC for class HLADR: 0.9921779999027189
# AUC for class MacCD163: 0.9914919020602395
# AUC for class Mural: 0.9986522379942779
# AUC for class NK: 0.9031610637230306
# AUC for class Neutrophil: 0.997151981473873
# AUC for class Treg: 0.9993921447737476
# AUC for class Tumor: 0.99483328478668
# AUC for class pDC: 0.9987665984359418
# AUC for class plasma: 0.9976712522871629
#               precision    recall  f1-score   support
#
#            B       0.94      0.95      0.94       161
#          BnT       0.91      0.92      0.91       133
#          CD4       0.90      0.95      0.93       210
#          CD8       0.95      0.96      0.95       343
#           DC       0.85      0.86      0.85       174
#        HLADR       0.83      0.45      0.58        84
#     MacCD163       0.80      0.81      0.81       183
#        Mural       0.94      0.95      0.95       426
#           NK       0.67      0.43      0.52        14
#   Neutrophil       0.97      0.85      0.91        82
#         Treg       0.89      0.86      0.88        29
#        Tumor       0.96      0.98      0.97      2062
#          pDC       0.96      0.84      0.90        58
#       plasma       0.79      0.76      0.77        41
#
#     accuracy                           0.93      4000
#    macro avg       0.88      0.83      0.85      4000
# weighted avg       0.93      0.93      0.93      4000

# %% [markdown]
# # Random Forest Clasifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, verbose=1)
evaluateMethod(rf_model)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# Overall Accuracy: 0.95775
# Macro-F1: 0.8776391987793132
# AUC for class B: 0.9996311151163524
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# AUC for class BnT: 0.9991240708442946
# AUC for class CD4: 0.9990966201784145
# AUC for class CD8: 0.997413403425357
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# AUC for class DC: 0.9985406865307545
# AUC for class HLADR: 0.996780607033416
# AUC for class MacCD163: 0.996168277951242
# AUC for class Mural: 0.9995504175960446
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# AUC for class NK: 0.9395563042075837
# AUC for class Neutrophil: 0.9998023506268753
# AUC for class Treg: 1.0
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# AUC for class Tumor: 0.9979270078545482
# AUC for class pDC: 0.9999825049423539
# AUC for class plasma: 0.9996057146729588
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
#               precision    recall  f1-score   support
#
#            B       0.96      0.96      0.96       161
#          BnT       0.93      0.94      0.93       133
#          CD4       0.92      0.96      0.94       210
#          CD8       0.96      0.99      0.97       343
#           DC       0.90      0.90      0.90       174
#        HLADR       0.91      0.75      0.82        84
#     MacCD163       0.82      0.85      0.83       183
#        Mural       0.97      0.99      0.98       426
#           NK       1.00      0.14      0.25        14
#   Neutrophil       0.99      0.93      0.96        82
#         Treg       0.97      1.00      0.98        29
#        Tumor       0.98      0.98      0.98      2062
#          pDC       1.00      0.86      0.93        58
#       plasma       0.94      0.78      0.85        41
#
#     accuracy                           0.96      4000
#    macro avg       0.95      0.86      0.88      4000
# weighted avg       0.96      0.96      0.96      4000
